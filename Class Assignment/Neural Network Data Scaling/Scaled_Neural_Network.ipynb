# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns

# new import for scaling
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Input Variables:
#
#
# ---
#
#
# 1. Number of times pregnant
#
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
#
# 3. Diastolic blood pressure (mm Hg)
#
# 4. Triceps skin fold thickness (mm)
#
# 5. 2-hour serum insulin (mu U/ml)
#
# 6. Body mass index (weight in kg/(height in m)^2)
#
# 7. Diabetes pedigree function
#
# 8. Age (years)
#
#
# Output Variable:
#
#
# ---
#
# Class variable (0 or 1)

# %%
data_path = './nn_data.txt'
dataset = pd.read_csv(data_path, header=None)
dataset.shape
print(dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# split into input (X) and output (y) variables
# split into input (X) and output (y) variables
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# %%
X.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %% [markdown]
# # **MAIN TASK: Data Scaling (Normalization)**
#
# Here I used MinMaxScaler() from *sklearn.preprocessing* to scale the data using the following snippet

# %%
# using min max scaler to scale 8 collums
X[np.arange(0, 8)] = MinMaxScaler().fit_transform(X[np.arange(0, 8)])

X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.352941  0.743719  0.590164  0.353535  0.000000  0.500745  0.234415
# 1  0.058824  0.427136  0.540984  0.292929  0.000000  0.396423  0.116567
# 2  0.470588  0.919598  0.524590  0.000000  0.000000  0.347243  0.253629
# 3  0.058824  0.447236  0.540984  0.232323  0.111111  0.418778  0.038002
# 4  0.000000  0.688442  0.327869  0.353535  0.198582  0.642325  0.943638
#
#           7
# 0  0.483333
# 1  0.166667
# 2  0.183333
# 3  0.000000
# 4  0.200000

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=200, batch_size=5)
# Out:
# Epoch 1/200
# 154/154 [==============================] - 1s 1ms/step - loss: 0.6812 - accuracy: 0.6406
# Epoch 2/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6612 - accuracy: 0.6510
# Epoch 3/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6488 - accuracy: 0.6510
# Epoch 4/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.6510
# Epoch 5/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6358 - accuracy: 0.6510
# Epoch 6/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6268 - accuracy: 0.6510
# Epoch 7/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6191 - accuracy: 0.6484
# Epoch 8/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6088 - accuracy: 0.6576
# Epoch 9/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5962 - accuracy: 0.6784
# Epoch 10/200
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100), "%")
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4419 - accuracy: 0.7917
# Accuracy: 79.17 %

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 1ms/step
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
